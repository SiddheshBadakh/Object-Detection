# %%
import cv2
from yolo_predictions import YOLO_Pred
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import cv2
# ----> 2 from yolo_predictions import YOLO_Pred
#
# File c:\Users\asus\Desktop\yolo opencv\2_prediction\yolo_predictions.py:6
#       4 import numpy as np
#       5 import os
# ----> 6 import yaml
#       7 from yaml.loader import SafeLoader
#      10 class YOLO_Pred():
#
# ModuleNotFoundError: No module named 'yaml'

# %%
yolo = YOLO_Pred('./Model11/weights/best.onnx','data.yaml')

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\asus\Desktop\yolo opencv\2_prediction

# %%
import cv2
import matplotlib.pyplot as plt

# Load the image
img = cv2.imread('C:/Users/asus/Desktop/yolo opencv/2_prediction/street_image.jpg')

if img is None:
    print("Image not found or unable to load.")
else:
    # Convert BGR (OpenCV default) to RGB for matplotlib
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    
    # Display the image using matplotlib
    plt.imshow(img_rgb)
    plt.axis('off')  # Hide axis
    plt.show()

# %%
# predictions
img_pred = yolo.predictions(img)

# %%
import cv2
import matplotlib.pyplot as plt

# Assuming 'img_pred' is your processed image
if img_pred is None:
    print("Prediction image not found or unable to load.")
else:
    # Convert BGR to RGB for matplotlib
    img_rgb = cv2.cvtColor(img_pred, cv2.COLOR_BGR2RGB)
    
    # Display the image using matplotlib
    plt.imshow(img_rgb)
    plt.title('Prediction Image')
    plt.axis('off')  # Hide axis for a cleaner display
    plt.show()
